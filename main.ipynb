# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    else:       
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.047s
#
# OK

# %%
print(greater(3,5)) # it should return 5
print(greater(10,5)) # it should return 10
print(greater(100,3)) # it should return 3
# Out:
# 5
# 10
# 100

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def largest_in_list(lst):
    i = 0
    for _ in lst:
        first_element = lst[0]
        break
    else:
        return None
    
    largest = first_element
    i = 0

    while True:
        next_index = i + 1
        found_next = False
        j = 0
        for _ in lst:
            if j == next_index:
                found_next = True
                break
            j += 1
        if not found_next:
            break
        
        if lst[next_index] > largest:
            largest = lst[next_index]
        i += 1
    return largest  

numbers = [3, 7, 2, 9, 4]
print(largest_in_list(numbers))
# Out:
# 9

# %%
# This will test your function 
test_greatest(largest_in_list)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.054s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
elements = [1, 2, 3, 5, 55, 11, 23, 64, 21, 87]

def sum_all(lst):
    total = 0
    for num in lst:
        total = total + num
    return total
print(sum_all(elements))  # it should return 272
# Out:
# 272

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.055s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    total = 1 # cannot start with 0 because it will always return 0
    for num in lst:
        total = total * num
    return total
print(mult_all(elements))
# Out:
# 48811593600

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.044s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
    if oper == "*":
        total = 1
        for num in arr:
            total = total * num
        return total
    elif oper == "+":
        total = 0
        for num in arr:
            total = total + num
        return total
    else:
        return None 
#your code here

print(oper_all(elements, "+"))
print(oper_all(elements, "*")) # it should return 9034560
# Out:
# 272
# 48811593600

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if n < 0:
        return None
    elif n == 0:
        return 1
    else:
        total = 1
        for i in range(1, n + 1):
            total = total * i
        return total

#need help with this one

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.049s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
    unique_list = []
    for i in lst_un:
        if i not in unique_list:
            unique_list.append(i)
    return unique_list

#your code here

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.105s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    #if the list is empty, no mode exists
    first_round = False
    for _ in arr:
        first_round = True
        break
    if not first_round:
        return None 
    #track element that appears most often
    mode = None
    max_count = 0
#Out loop that goes through each element
    for element in arr:
        count = 0
        #inner loop that counts how many times the element appears
        for other in arr:
            if other == element:
                count += 1
        if count > max_count:
            max_count = count
            mode = element
    return mode

numbers = [1, 2, 106, 2, 3, 1, 4, 106, 5, 1, 7, 8, 5, 9, 7, 3, 106, 106, 8, 106]
print(mode_counter(numbers))
# Out:
# 106

# %%
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.125s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
    # 1 Check if the list is empty
    first_round = False
    for _ in list_sd:
        first_round = True
        break  
    if not first_round:
        return None
    
    # 2 Calculate Count and Total sum manually
    total = 0
    count = 0
    for x in list_sd:
        total = total + x
        count = count + 1
    
    # 3 Calculate Mean
    mean = total / count 
    
    # 4 Sum of squared differences from the mean
    squarediff = 0
    for x in list_sd:
        diff = x - mean
        squarediff = squarediff + (diff * diff)
    
    #5 Calculate Variance
    variance = squarediff / (count - 1)# failing here!!
    #this was the line that was giving error. Expected "x-1" not "x"
    
    #6 Square root mannually
    if variance == 0:
        return 0
    
    guess = variance if variance > 1 else 1
    for _ in range(50):  # more iterations for more precision
        guess = (guess + variance / guess) / 2
    return guess

#use exmple list
#nums = [2, 4, 4, 4, 5, 5, 7, 9,]
#print(st_dev(nums))  # it should return 2.581988897471611

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.042s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    # Step 1: prepare a list of lowercase alphabet letters
    alphabet = []
    code = 97  # ASCII code for 'a'
    while code <= 122:  # 'z'
        alphabet = alphabet + [chr(code)]
        code = code + 1

    # Step 2: make all characters in the string lowercase manually
    lower_string = ""
    for ch in string:
        # manual lowercase conversion (without .lower())
        # if it's uppercase A-Z (65–90), convert to a-z (+32)
        c = ch
        ascii_code = ord(ch)
        if ascii_code >= 65 and ascii_code <= 90:
            c = chr(ascii_code + 32)
        lower_string = lower_string + c

    # Step 3: track which letters we’ve seen
    found_letters = []
    for ch in lower_string:
        # check if character is between 'a' and 'z'
        a = 97
        while a <= 122:
            if chr(a) == ch:
                # manually check if we've already seen it
                already = False
                for f in found_letters:
                    if f == ch:
                        already = True
                        break
                if not already:
                    found_letters = found_letters + [ch]
                break
            a = a + 1

    # Step 4: check if we have all 26 letters
    count = 0
    for _ in found_letters:
        count = count + 1

    if count == 26:
        return True
    else:
        return False
    
print(pangram("The quick brown fox jumps over the lazy dog"))  # True
print(pangram("Hello world"))  # False
print(pangram("Pack my box with five dozen liquor jugs"))  # True
# Out:
# True
# False
# True

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.014s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    # Step 1: manually split the string by commas into a list of words
    words = []
    word = ""
    for ch in string:
        if ch == ",":
            words = words + [word]
            word = ""
        else:
            word = word + ch
    # add the last word
    words = words + [word]

    # Step 2: sort the list alphabetically (allowed)
    sorted_words = sorted(words)

    # Step 3: manually rebuild a comma-separated string
    result = ""
    index = 0
    for w in sorted_words:
        if index == 0:
            result = result + w
        else:
            result = result + "," + w
        index = index + 1

    return result



print(sort_alpha("catfish,ants,fox,elephant,zebra,worm"))  
print(sort_alpha("dog,cat,bird,ant"))
# Out:
# ants,catfish,elephant,fox,worm,zebra
# ant,bird,cat,dog

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
    count = 0
    for _ in password:
        count = count + 1
    if count < 8:
        return False
    
    has_lower = False
    has_upper = False
    has_digit = False
    has_special = False
   # special_characters = "!@#$%^&*()-+?_=,<>/" #note this

    for ch in password:
        code = ord(ch)

        if code >= 97 and code <= 122:
            has_lower = True
        
        elif code >= 65 and code <= 90:
            has_upper = True   
        
        elif code >= 48 and code <= 57:
            has_digit = True
        
        #this had to be added, otherwise all the passwords were failing
        elif not (code >= 48 and code <= 57) and not (code >= 65 and code <= 90) and not (code >= 97 and code <= 122):
            has_special = True

    if has_lower and has_upper and has_digit and has_special:
        return True
    else:
        return False    
    
        








print(check_pass("Password123!")) 
print(check_pass("pass123!"))
print(check_pass("PASSWORD!1"))
print(check_pass("Passwor"))
print(check_pass("Pa$$word9")) 
print(check_pass("Takethis1!"))
# Out:
# True
# False
# False
# False
# True
# True

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.039s
#
# OK
